# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmikant-hunachal/DSA-IN-JAVA/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr=np.array([1,2,3,4,5,6])
print(arr)
# Out:
# [1 2 3 4 5 6]

# %%
print(arr.min())
# Out:
# 1

# %%
import pandas as pd
s=pd.Series([10,20,30,40,50])
s
s.dtype
s.name
s.name="numbers"
s
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)
